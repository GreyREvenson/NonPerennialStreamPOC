# %% [markdown]
# ###### import modules

# %%
import os,sys,folium
src = r'../../../src'
sys.path.append(os.path.abspath(src))
import twtnamelist,twtmapfolium

# %% [markdown]
# ###### initialize namelist object

# %%
fname_namelist = '../namelist.yaml'
namelist = twtnamelist.Namelist(filename=fname_namelist)

# %% [markdown]
# ###### make texture map and show

# %%
map = twtmapfolium.twtfoliummap(namelist=namelist)
map.add_texture()
folium.LayerControl().add_to(map)
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5b5bb5a317694210634c6b88071b558 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#         &lt;div style=&quot;position: fixed;
#         top: 10px; left: 60px; width: 200px; height: auto;
#         border:2px solid grey; z-index:9999; font-size:14px;
#         background-color:white; opacity: 0.85; padding: 10px;&quot;&gt;
#         &lt;b&gt;Soil Texture&lt;/b&gt;&lt;br&gt;
#         &lt;div style=&quot;display: flex; align-items: center; margin-bottom: 5px;&quot;&gt;&lt;div style=&quot;width: 20px; height: 20px; background-color: #440154ff; margin-right: 5px;&quot;&gt;&lt;/div&gt;loam&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center; margin-bottom: 5px;&quot;&gt;&lt;div style=&quot;width: 20px; height: 20px; background-color: #21908cff; margin-right: 5px;&quot;&gt;&lt;/div&gt;sandy loam&lt;/div&gt;&lt;div style=&quot;display: flex; align-items: center; margin-bottom: 5px;&quot;&gt;&lt;div style=&quot;width: 20px; height: 20px; background-color: #fde725ff; margin-right: 5px;&quot;&gt;&lt;/div&gt;silt loam&lt;/div&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5b5bb5a317694210634c6b88071b558&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5b5bb5a317694210634c6b88071b558 = L.map(
#                 &quot;map_d5b5bb5a317694210634c6b88071b558&quot;,
#                 {
#                     center: [37.44595019743128, -83.12968931695102],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e355a061130896da05fcf1179a0a3688 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e355a061130896da05fcf1179a0a3688.addTo(map_d5b5bb5a317694210634c6b88071b558);
#
#
#             var feature_group_a04427ff8649b7d566fe1fb0dd1946d9 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_7b9e6d72f4e272e1613a5a90303245da_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;none&quot;};
#             }
#         }
#
#         function geo_json_7b9e6d72f4e272e1613a5a90303245da_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_7b9e6d72f4e272e1613a5a90303245da = L.geoJson(null, {
#                 onEachFeature: geo_json_7b9e6d72f4e272e1613a5a90303245da_onEachFeature,
#
#                 style: geo_json_7b9e6d72f4e272e1613a5a90303245da_styler,
#             ...{
# }
#         });
#
#         function geo_json_7b9e6d72f4e272e1613a5a90303245da_add (data) {
#             geo_json_7b9e6d72f4e272e1613a5a90303245da
#                 .addData(data);
#         }
#             geo_json_7b9e6d72f4e272e1613a5a90303245da_add({&quot;bbox&quot;: [-83.21603324796871, 37.39978480435785, -83.03942448377207, 37.5049420792161], &quot;features&quot;: [{&quot;bbox&quot;: [-83.21603324796871, 37.39978480435785, -83.03942448377207, 37.5049420792161], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-83.12254551436662, 37.50146635275669], [-83.12270087440176, 37.50151037207317], [-83.12320843780866, 37.501687993425456], [-83.12401780909987, 37.50186481047062], [-83.12578899219272, 37.5020034205678], [-83.12657338852242, 37.502007950961975], [-83.12739417470594, 37.50176395923394], [-83.12880617900886, 37.50181891420594], [-83.12900525915055, 37.501993049905145], [-83.12949869565128, 37.50286545334594], [-83.12972266092298, 37.50370295829935], [-83.13029763660373, 37.50382780024913], [-83.13112968855923, 37.50419395130992], [-83.13171348659438, 37.50402017421491], [-83.13213331154748, 37.503948529323225], [-83.1328114641285, 37.503640849741764], [-83.13339183509085, 37.50356449673743], [-83.13397622870905, 37.504401822815865], [-83.13451422074955, 37.5049420792161], [-83.13543123716124, 37.504510570086275], [-83.13609889921639, 37.50435443655548], [-83.13688761823921, 37.504385102868035], [-83.13748366480328, 37.50464703664772], [-83.13775090282053, 37.504648197533506], [-83.13827303959626, 37.504118580892154], [-83.13878695049894, 37.50333185904232], [-83.13942501845537, 37.50254519731751], [-83.13954276782619, 37.502040196071896], [-83.1393196676321, 37.5014692440484], [-83.13946089986275, 37.50147442941629], [-83.14023891995055, 37.50136609819788], [-83.14106352127908, 37.50125669282949], [-83.14193467240732, 37.501098889832754], [-83.14277018108005, 37.501465727034656], [-83.14360783582796, 37.50177081292903], [-83.14444119932378, 37.50219943023937], [-83.14542971085231, 37.5020874925804], [-83.14589096251306, 37.50122677210988], [-83.

# %%
#map_transmissivity = domain.get_fmap_transmissivity(namelist=namelist)
#display(map_transmissivity)

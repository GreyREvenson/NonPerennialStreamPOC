# %% [markdown]
# ###### import modules

# %%
import os,sys,folium
src = r'../../../src'
sys.path.append(os.path.abspath(src))
import twtnamelist,twtmapfolium

# %% [markdown]
# ###### initialize namelist object

# %%
fname_namelist = '../namelist.yaml'
namelist = twtnamelist.Namelist(filename=fname_namelist)

# %% [markdown]
# ###### make twi map and show

# %%
map = twtmapfolium.twtfoliummap(nl=namelist)
map.add_nonperennial_strm_classification(namelist=namelist)
map.add_perennial_strm_classification(namelist=namelist)
folium.LayerControl().add_to(map)
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_feea95f024d1bf0c9ba716506cdffc27 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
#
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#         &lt;div style=&quot;position: fixed;
#         bottom: 10px; left: 10px; width: 200px; height: auto;
#         border:2px solid grey; z-index:9999; font-size:14px;
#         background-color:white; opacity: 0.85; padding: 10px;&quot;&gt;
#         &amp;nbsp; &lt;b&gt;WTD-TWI Classification&lt;/b&gt; &lt;br&gt;
#         &lt;div style=&quot;display: flex; align-items: center; margin-bottom: 5px;&quot;&gt;&lt;div style=&quot;width: 20px; height: 20px; background-color: #ff0000ff; margin-right: 5px;&quot;&gt;&lt;/div&gt;Perennial&lt;/div&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_feea95f024d1bf0c9ba716506cdffc27&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_feea95f024d1bf0c9ba716506cdffc27 = L.map(
#                 &quot;map_feea95f024d1bf0c9ba716506cdffc27&quot;,
#                 {
#                     center: [34.96316525283662, -86.17970365290539],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d26c841a97d19f9c75bb84c75e665e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8d26c841a97d19f9c75bb84c75e665e0.addTo(map_feea95f024d1bf0c9ba716506cdffc27);
#
#
#             var feature_group_12c95306d9d17463cdd0d4dc9af12954 = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_5a648117282374d37212ea55fbacbbf9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;none&quot;};
#             }
#         }
#
#         function geo_json_5a648117282374d37212ea55fbacbbf9_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_5a648117282374d37212ea55fbacbbf9 = L.geoJson(null, {
#                 onEachFeature: geo_json_5a648117282374d37212ea55fbacbbf9_onEachFeature,
#
#                 style: geo_json_5a648117282374d37212ea55fbacbbf9_styler,
#             ...{
# }
#         });
#
#         function geo_json_5a648117282374d37212ea55fbacbbf9_add (data) {
#             geo_json_5a648117282374d37212ea55fbacbbf9
#                 .addData(data);
#         }
#             geo_json_5a648117282374d37212ea55fbacbbf9_add({&quot;bbox&quot;: [-86.19370748493577, 34.95310767467713, -86.16459554875726, 34.970541482733196], &quot;features&quot;: [{&quot;bbox&quot;: [-86.19370748493577, 34.95310767467713, -86.16459554875726, 34.970541482733196], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-86.17302702757549, 34.970541482733196], [-86.173005120303, 34.97054133354063], [-86.17300530155006, 34.970523300453905], [-86.17295053338155, 34.97052292745546], [-86.17295062401102, 34.97051391091221], [-86.17273155137106, 34.970512418671944], [-86.17273164202449, 34.97050340212917], [-86.172676873873, 34.97050302900749], [-86.17267696453239, 34.97049401246483], [-86.17263315001674, 34.970493713949814], [-86.17263305935255, 34.97050273049237], [-86.17262210572254, 34.97050265586111], [-86.17262219638792, 34.97049363931858], [-86.17261124275915, 34.970493564686365], [-86.1726116054251, 34.9704574985161
